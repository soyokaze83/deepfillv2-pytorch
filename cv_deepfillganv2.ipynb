# %%
# !git clone -b feat/emoji-inpainting https://github.com/soyokaze83/deepfillv2-pytorch.git
# Out:
# Cloning into 'deepfillv2-pytorch'...
# remote: Enumerating objects: 221, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 221 (delta 28), reused 34 (delta 18), pack-reused 169 (from 1)
# Receiving objects: 100% (221/221), 3.43 MiB | 9.29 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118
# !pip install tensorboard numpy pyyaml Pillow
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...

# %%
# !python deepfillv2-pytorch/train.py --config deepfillv2-pytorch/configs/train-emoji.yaml
# Out:
# Created checkpoint_dir folder: checkpoints/emoji/model_exp1
# Loaded models from: drive/MyDrive/computer-vision/pretrained/states_pt_celebahq.pth!
# 2025-11-27 07:49:43.178932: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764229783.195854   13645 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764229783.200791   13645 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764229783.214950   13645 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# TODO: Install pre-trained weights
