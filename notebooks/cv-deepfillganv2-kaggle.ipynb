# %%
# !rm -rf deepfillv2-pytorch && git clone -b feat/emoji-inpainting https://github.com/soyokaze83/deepfillv2-pytorch.git

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu113
# !pip install tensorboard numpy pyyaml Pillow

# %%
# !cat /kaggle/working/deepfillv2-pytorch/configs/emoji/train-emoji-no_ft.yaml

# %%
# !python /kaggle/working/deepfillv2-pytorch/train.py --config /kaggle/working/deepfillv2-pytorch/configs/emoji/train-emoji-no_ft.yaml
